# %% [markdown]
# ## OSRM (Open Source Routing Machine)
#
# **Author**: SADDIK Imad
# <br/>
# **Date**: 31/12/2024
#
# ---

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Trip service](#toc1_)
#   - [Loading the data](#toc1_1_)
#   - [Plotting the data](#toc1_2_)
#   - [Using the service](#toc1_3_)
#     - [General options](#toc1_3_1_)
#     - [Additional options](#toc1_3_2_)
#     - [Making the request](#toc1_3_3_)
#       - [No source & No destination](#toc1_3_3_1_)
#       - [Fixed source & Fixed destination](#toc1_3_3_2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ---

# %% [markdown]
# # <a id='toc1_'></a>[Trip service](#toc0_)

# %% [markdown]
# Use this service if you want to solve the TSP problem. Read more about it [here](https://project-osrm.org/docs/v5.24.0/api/?language=cURL#trip-service).

# %% [markdown]
# ## <a id='toc1_1_'></a>[Loading the data](#toc0_)

# %% [markdown]
# Since, I am working with the `Morocco` map, I randomly selected some cities from that country to demonstrate how the `Trip` service works. If you are using another country, make sure to use your own data.

# %%
import pandas as pd
from pydantic import BaseModel


class Point(BaseModel):
    latitude: float
    longitude: float


df = pd.read_csv("D:/A-HKU/OSRM_Learning/notebook/data/trip_service_data.csv")
points = []
for i, row in df.iterrows():
    latitude = row["latitude"]
    longitude = row["longitude"]
    points.append(Point(latitude=latitude, longitude=longitude))

points[:5]
# Out:
# [Point(latitude=22.14839107, longitude=113.4477153),
#  Point(latitude=22.1092719, longitude=113.4312568),
#  Point(latitude=22.20557892, longitude=113.4609378),
#  Point(latitude=22.23426286, longitude=113.5016648),
#  Point(latitude=22.22157594, longitude=113.4440119)]

# %% [markdown]
# ## <a id='toc1_2_'></a>[Plotting the data](#toc0_)

# %%
import folium

folium_map = folium.Map(
    location=[points[0].latitude, points[0].longitude], zoom_start=12)

for point in points:
    folium.Marker(
        location=[point.latitude, point.longitude],
        icon=folium.Icon(color='blue')
    ).add_to(folium_map)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9dadc938fc169cc2920370e17324b3f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9dadc938fc169cc2920370e17324b3f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9dadc938fc169cc2920370e17324b3f9 = L.map(
#                 &quot;map_9dadc938fc169cc2920370e17324b3f9&quot;,
#                 {
#                     center: [22.14839107, 113.4477153],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0673ff0ee837ac211e979299d3b11b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0673ff0ee837ac211e979299d3b11b2.addTo(map_9dadc938fc169cc2920370e17324b3f9);
#
#
#             var marker_666aac81b58408856a919ae8b3cf5959 = L.marker(
#                 [22.14839107, 113.4477153],
#                 {
# }
#             ).addTo(map_9dadc938fc169cc2920370e17324b3f9);
#
#
#             var icon_cd43cd2bd2f5ed7baf18eeaf2b0c1d28 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_666aac81b58408856a919ae8b3cf5959.setIcon(icon_cd43cd2bd2f5ed7baf18eeaf2b0c1d28);
#
#
#             var marker_4489a562276e543c2d0e035df7d823d9 = L.marker(
#                 [22.1092719, 113.4312568],
#                 {
# }
#             ).addTo(map_9dadc938fc169cc2920370e17324b3f9);
#
#
#             var icon_61a0dd41ea1f1efa31a895fef06d7714 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_4489a562276e543c2d0e035df7d823d9.setIcon(icon_61a0dd41ea1f1efa31a895fef06d7714);
#
#
#             var marker_6a703c8548ed7c3d2536fea305ac3a4e = L.marker(
#                 [22.20557892, 113.4609378],
#                 {
# }
#             ).addTo(map_9dadc938fc169cc2920370e17324b3f9);
#
#
#             var icon_7504ee8933262adf860defefb387cae0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_6a703c8548ed7c3d2536fea305ac3a4e.setIcon(icon_7504ee8933262adf860defefb387cae0);
#
#
#             var marker_16737234e176d9425d1833c933500519 = L.marker(
#                 [22.23426286, 113.5016648],
#                 {
# }
#             ).addTo(map_9dadc938fc169cc2920370e17324b3f9);
#
#
#             var icon_1ce79947696419f8f7a7c99569490246 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_16737234e176d9425d1833c933500519.setIcon(icon_1ce79947696419f8f7a7c99569490246);
#
#
#             var marker_9d7c5a54dd7b0574c77a9961418129cc = L.marker(
#                 [22.22157594, 113.4440119],
#                 {
# }
#             ).addTo(map_9dadc938fc169cc2920370e17324b3f9);
#
#
#             var icon_d619e0054b36c2402ed113f33850aebb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_9d7c5a54dd7b0574c77a9961418129cc.setIcon(icon_d619e0054b36c2402ed113f33850aebb);
#
#
#             var marker_cd4b3f3ac45b64cb922af1e997df2908 = L.marker(
#                 [22.28366828, 113.4107466],
#                 {
# }
#             ).addTo(map_9dadc938fc169cc2920370e17324b3f9);
#
#
#             var icon_15a3f76c24983108e959ae4e0bee981b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&q

# %% [markdown]
# ## <a id='toc1_3_'></a>[Using the service](#toc0_)

# %% [markdown]
# ### <a id='toc1_3_1_'></a>[General options](#toc0_)

# %% [markdown]
# The general options are used in every OSRM service, read more about them [here](https://project-osrm.org/docs/v5.5.1/api/?language=cURL#general-options). Here is a table that summarizes the options with their description.
#
#
# | Parameter | Description |
# |-----------|-------------|
# | service | One of the following values: `route`, `nearest`, `table`, `match`, `trip`, `tile` |
# | version | Version of the protocol implemented by the service. `v1` for all OSRM 5.x installations |
# | profile | Mode of transportation, is determined statically by the Lua profile that is used to prepare the data using `osrm-extract`. Typically `car`, `bike` or `foot` if using one of the supplied profiles. |
# | coordinates | String of format `{longitude},{latitude};{longitude},{latitude};{longitude},{latitude} ...]` or `polyline({polyline})`. |
# | format | Only `json` is supported at the moment. This parameter is optional and defaults to `json`. |

# %% [markdown]
# ### <a id='toc1_3_2_'></a>[Additional options](#toc0_)

# %% [markdown]
# The additional parameters available for requests to the trip service are:
#
# - `roundtrip`: A boolean indicating whether the returned route is a roundtrip (i.e., the route returns to the starting location).
# - `source`: A string specifying the starting point of the returned route, which can be either `any` or `first` coordinate.
# - `destination`: A string specifying the endpoint of the returned route, which can be either `any` or `last` coordinate.

# %% [markdown]
# ### <a id='toc1_3_3_'></a>[Making the request](#toc0_)

# %% [markdown]
# The trip endpoint follows this format: `/trip/v1/{profile}/{coordinates}?roundtrip={true|false}&source{any|first}&destination{any|last}&steps={true|false}&geometries={polyline|polyline6|geojson}&overview={simplified|full|false}&annotations={true|false}`.

# %% [markdown]
# #### <a id='toc1_3_3_1_'></a>[No source & No destination](#toc0_)

# %% [markdown]
# This is the default case. OSRM will choose the start and end points randonly since they are not specified in the request. Also, by default, OSRM will start and finish at the same point.

# %%
service = 'trip'
version = 'v1'
profile = 'cycling'
host = 'http://localhost:5000'

# %%
import requests

coordinates = ';'.join(
    [f'{point.longitude},{point.latitude}' for point in points])
url = f'{host}/{service}/{version}/{profile}/{coordinates}'
params = {
    "steps": "true",
    "geometries": "geojson",
    "overview": "full",
    "annotations": "true",
}

response = requests.get(url, params=params)
response.status_code
# Out:
# 200

# %% [markdown]
# The trip can be extracted from the `trip` field. OSRM will return the fastest trip.

# %%
data = response.json()
data.keys()
# Out:
# dict_keys(['code', 'trips', 'waypoints'])

# %% [markdown]
# This looks familiar, we have seen such an output in the first notebook where we talked about the `route` service. We will use the legs to draw the snapped route.

# %%
trip = data['trips'][0]
trip.keys()
# Out:
# dict_keys(['legs', 'weight_name', 'geometry', 'weight', 'duration', 'distance'])

# %% [markdown]
# Let's create some helper function to add markers to the map, draw polylines and create the HTML for the popup.

# %%
from folium import Map


def create_marker(
    map_obj: Map,
    point: Point,
    label: str,
    background_color: str,
    y_offset: int = 0
) -> None:
    folium.Marker(
        location=[point.latitude, point.longitude],
        icon=folium.DivIcon(html=f'''
            <div style="
                background-color: {background_color};
                border-radius: 5px;
                padding: 2px 5px;
                font-size: 8pt;
                text-align: center;
                width: 20px;
                height: 20px;
                line-height: 20px;
                transform: translate(0px, {y_offset}px);
                ">
                {label}
            </div>
        ''')
    ).add_to(map_obj)


def add_polyline(
    map_obj: Map,
    coordinates: list[Point],
    color: str,
    popup_html: str
) -> None:
    folium.PolyLine(
        locations=[[point.latitude, point.longitude] for point in coordinates],
        color=color,
        popup=folium.Popup(popup_html, max_width=300)
    ).add_to(map_obj)


def get_popup_html(leg: dict, i: int) -> str:
    distance_km = leg['distance'] / 1000
    duration_sec = leg['duration']
    hours, remainder = divmod(duration_sec, 3600)
    minutes, seconds = divmod(remainder, 60)
    return f"""Leg number: {i + 1}<br>Distance: {distance_km:.2f} km<br>Duration: {int(hours):02}:{int(minutes):02}:{int(seconds):02}"""

# %% [markdown]
# The start point is colored in `green` while the end point is colored in `red`. As you can see, both points are the same, that is because by default OSRM will make a roundtrip, meaning it will start at a point and go back to it at the end of the trip.

# %%
folium_map = folium.Map(
    location=[points[0].latitude, points[0].longitude], zoom_start=6)

colors = ["red", "black"]
legs = trip['legs']

for i, leg in enumerate(legs):
    start_coords = leg["steps"][0]["geometry"]["coordinates"][0]
    starting_point = Point(latitude=start_coords[1], longitude=start_coords[0])
    create_marker(
        map_obj=folium_map,
        point=starting_point,
        label=i+1,
        background_color="#93ff6a" if i == 0 else "#6aaeff",
        y_offset=10 if i == 0 else 0
    )

    for step in leg["steps"]:
        coordinates = [Point(latitude=lat, longitude=lon, timestamp=0)
                       for lon, lat in step["geometry"]["coordinates"]]

        add_polyline(
            map_obj=folium_map,
            coordinates=coordinates,
            color=colors[i % len(colors)],
            popup_html=get_popup_html(leg=leg, i=i)
        )

end_coords = legs[-1]["steps"][-1]["geometry"]["coordinates"][-1]
end_point = Point(latitude=end_coords[1], longitude=end_coords[0])
create_marker(
    map_obj=folium_map,
    point=end_point,
    label=len(legs) + 1,
    background_color="#ff6a6a",
    y_offset=-10
)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d86c116688450cb8c6600f93717c697e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d86c116688450cb8c6600f93717c697e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d86c116688450cb8c6600f93717c697e = L.map(
#                 &quot;map_d86c116688450cb8c6600f93717c697e&quot;,
#                 {
#                     center: [22.14839107, 113.4477153],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3475f715bda4b27c3311f7a3227506d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3475f715bda4b27c3311f7a3227506d8.addTo(map_d86c116688450cb8c6600f93717c697e);
#
#
#             var marker_18c26c229cc5cea664820988ca85b481 = L.marker(
#                 [22.148395, 113.447722],
#                 {
# }
#             ).addTo(map_d86c116688450cb8c6600f93717c697e);
#
#
#             var div_icon_c2efc4e72d8378afe4877994a57e2325 = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;\n                background-color: #93ff6a;\n                border-radius: 5px;\n                padding: 2px 5px;\n                font-size: 8pt;\n                text-align: center;\n                width: 20px;\n                height: 20px;\n                line-height: 20px;\n                transform: translate(0px, 10px);\n                \&quot;\u003e\n                1\n            \u003c/div\u003e\n        &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_18c26c229cc5cea664820988ca85b481.setIcon(div_icon_c2efc4e72d8378afe4877994a57e2325);
#
#
#             var poly_line_c1580efd2cea502a4efd394e32eed8b7 = L.polyline(
#                 [[22.148395, 113.447722], [22.148283, 113.447795]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d86c116688450cb8c6600f93717c697e);
#
#
#         var popup_d2d18ef75e9537fd37d5e44cade2a102 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_d0994aaa01aac658375f5014e36e3d3c = $(`&lt;div id=&quot;html_d0994aaa01aac658375f5014e36e3d3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Leg number: 1&lt;br&gt;Distance: 3.72 km&lt;br&gt;Duration: 00:15:51&lt;/div&gt;`)[0];
#                 popup_d2d18ef75e9537fd37d5e44cade2a102.setContent(html_d0994aaa01aac658375f5014e36e3d3c);
#
#
#
#         poly_line_c1580efd2cea502a4efd394e32eed8b7.bindPopup(popup_d2d18ef75e9537fd37d5e44cade2a102)
#         ;
#
#
#
#
#             var poly_line_d654e70bfe458f8098635e6b4eccece5 = L.polyline(
#                 [[22.148283, 113.447795], [22.146959, 113.446072], [22.146478, 113.445445], [22.146368, 113.445302], [22.146012, 113.444834], [22.145914, 113.444706], [22.14584, 113.444608]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d86c116688450cb8c6600f93717c697e);
#
#
#         var popup_2f7f3188796a6318f7df17bbc804c189 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_5cb56b45211d77ae78d78624989978a7 = $(`&lt;div id=&quot;html_5cb56b45211d77ae78d78624989978a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Leg number: 1&lt;br&gt;Distance: 3.72 km&lt;br&gt;Duration: 00:15:51&lt;/div&gt;`)[0];
#                 popup_2f7f3188796a6318f7df17bbc804c189.setContent(html_5cb56b45211d77ae78d78624989978a7);
#
#
#
#         poly_line_d654e70bfe458f8098635e6b4eccece5.bindPopup(popup_2f7f3188796a6318f7df17bbc804c189)
#         ;
#
#
#
#
#             var poly_line_cc0ab2b95125f6b8f78163d540c0cc83 = L.polyline(

# %% [markdown]
# #### <a id='toc1_3_3_2_'></a>[Fixed source & Fixed destination](#toc0_)

# %% [markdown]
# I only added three parameters to the request `roundtrip`, `source`, and `destination`.

# %%
coordinates = ';'.join(
    [f'{point.longitude},{point.latitude}' for point in points])
url = f'{host}/{service}/{version}/{profile}/{coordinates}'
params = {
    "steps": "true",
    "geometries": "geojson",
    "overview": "full",
    "annotations": "true",
    "source": "first",
    "destination": "last",
    "roundtrip": "false",
}

response = requests.get(url, params=params)
data = response.json()
trip = data['trips'][0]

# %% [markdown]
# As you can see, the start and end points are no longer the same.

# %%
folium_map = folium.Map(
    location=[points[0].latitude, points[0].longitude], zoom_start=6)

colors = ["red", "black"]
legs = trip['legs']

for i, leg in enumerate(legs):
    start_coords = leg["steps"][0]["geometry"]["coordinates"][0]
    starting_point = Point(latitude=start_coords[1], longitude=start_coords[0])
    create_marker(
        map_obj=folium_map,
        point=starting_point,
        label=i+1,
        background_color="#93ff6a" if i == 0 else "#6aaeff",
        y_offset=0
    )

    for step in leg["steps"]:
        coordinates = [Point(latitude=lat, longitude=lon, timestamp=0)
                       for lon, lat in step["geometry"]["coordinates"]]

        add_polyline(
            map_obj=folium_map,
            coordinates=coordinates,
            color=colors[i % len(colors)],
            popup_html=get_popup_html(leg=leg, i=i)
        )

end_coords = legs[-1]["steps"][-1]["geometry"]["coordinates"][-1]
end_point = Point(latitude=end_coords[1], longitude=end_coords[0])
create_marker(
    map_obj=folium_map,
    point=end_point,
    label=len(legs) + 1,
    background_color="#ff6a6a",
    y_offset=0
)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08d78341b3a2ee7996daac7fbfb846ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08d78341b3a2ee7996daac7fbfb846ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08d78341b3a2ee7996daac7fbfb846ea = L.map(
#                 &quot;map_08d78341b3a2ee7996daac7fbfb846ea&quot;,
#                 {
#                     center: [33.89359590935516, -5.503361694553792],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90708d5288cbce5286c0c6caf0b1f41e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_90708d5288cbce5286c0c6caf0b1f41e.addTo(map_08d78341b3a2ee7996daac7fbfb846ea);
#
#
#             var marker_eba68bf1f7e499393362b1566abac640 = L.marker(
#                 [33.893593, -5.503362],
#                 {
# }
#             ).addTo(map_08d78341b3a2ee7996daac7fbfb846ea);
#
#
#             var div_icon_c5e9ab062b8872325ca823676e3e71f5 = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;\n                background-color: #93ff6a;\n                border-radius: 5px;\n                padding: 2px 5px;\n                font-size: 8pt;\n                text-align: center;\n                width: 20px;\n                height: 20px;\n                line-height: 20px;\n                transform: translate(0px, 0px);\n                \&quot;\u003e\n                1\n            \u003c/div\u003e\n        &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_eba68bf1f7e499393362b1566abac640.setIcon(div_icon_c5e9ab062b8872325ca823676e3e71f5);
#
#
#             var poly_line_e3bac3cd31b30b5554b2eaaebc38655f = L.polyline(
#                 [[33.893593, -5.503362], [33.893583, -5.503245]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_08d78341b3a2ee7996daac7fbfb846ea);
#
#
#         var popup_1e445e15485a3e82818e0a8f897cecd2 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_94e5bad69ec12855c5c59b2f486ce970 = $(`&lt;div id=&quot;html_94e5bad69ec12855c5c59b2f486ce970&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Leg number: 1&lt;br&gt;Distance: 71.62 km&lt;br&gt;Duration: 00:55:31&lt;/div&gt;`)[0];
#                 popup_1e445e15485a3e82818e0a8f897cecd2.setContent(html_94e5bad69ec12855c5c59b2f486ce970);
#
#
#
#         poly_line_e3bac3cd31b30b5554b2eaaebc38655f.bindPopup(popup_1e445e15485a3e82818e0a8f897cecd2)
#         ;
#
#
#
#
#             var poly_line_8d381f555a2ba348b55c44878214a612 = L.polyline(
#                 [[33.893583, -5.503245], [33.893519, -5.503249], [33.893395, -5.503254], [33.89327, -5.503264], [33.893166, -5.503275], [33.892946, -5.503303], [33.892741, -5.503331], [33.892586, -5.503355]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_08d78341b3a2ee7996daac7fbfb846ea);
#
#
#         var popup_9c85671b994c7c0235876027db581f8c = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_d2250309eaa5bcc5552aad07e4d79e62 = $(`&lt;div id=&quot;html_d2250309eaa5bcc5552aad07e4d79e62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Leg number: 1&lt;br&gt;Distance: 71.62 km&lt;br&gt;Duration: 00:55:31&lt;/div&gt;`)[0];
#                 popup_9c85671b994c7c0235876027db581f8c.setContent(html_d2250309eaa5bcc5552aad07e4d79e62);
#
#
#
#         poly_line_8d381f555a2ba348b55c44878214a612.bindPopup(popup_9c85671b994c7c0235876027db581f8c)
#         ;
#
#
#
#
#             var poly_line_3dcb26b194424328b544392
