# %% [markdown]
# ## OSRM (Open Source Routing Machine)
#
# **Author**: SADDIK Imad
# <br/>
# **Date**: 26/12/2024
#
# ---

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Route service](#toc1_)
#   - [Setup](#toc1_1_)
#   - [Using the service](#toc1_2_)
#     - [General options](#toc1_2_1_)
#     - [Making the request](#toc1_2_2_)
#     - [Plotting the path](#toc1_2_3_)
#     - [Exploring legs](#toc1_2_4_)
#     - [Exploring the intersections](#toc1_2_5_)
#     - [Exploring the cost of the route](#toc1_2_6_)
#     - [Alternative routes](#toc1_2_7_)

# %% [markdown]
# ---

# %% [markdown]
# # <a id='toc1_'></a>[Route service](#toc0_)

# %% [markdown]
# Use this service if you want to find the fastest route between coordinates. Read more about it [here](https://project-osrm.org/docs/v5.24.0/api/?language=cURL#route-service).

# %% [markdown]
# ## <a id='toc1_1_'></a>[Setup](#toc0_)

# %% [markdown]
# I selected four points from the map, designating one as the center. Using the `Folium` package, I will visualize these points on the map.

# %%
import folium
from folium import Map
from pydantic import BaseModel

class Point(BaseModel):
    latitude: float
    longitude: float

def get_folium_map(center_point: Point, points: list[Point], zoom_level: int = 12) -> Map:
    folium_map = folium.Map(
        location=[center_point.latitude, center_point.longitude], zoom_start=zoom_level)

    for point in points:
        folium.Marker(location=[point.latitude, point.longitude],
                      popup='Point').add_to(folium_map)

    return folium_map

point_1 = Point(latitude=22.0064, longitude=113.3763)
point_2 = Point(latitude=22.1190, longitude=113.3572)
point_3 = Point(latitude=22.0653, longitude=113.1167)
center_point = Point(latitude=22.0636, longitude=113.2834)

folium_map = get_folium_map(center_point, [point_1, point_2, point_3])
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6d9b2c00742f1136373e7ecdfebe12e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6d9b2c00742f1136373e7ecdfebe12e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6d9b2c00742f1136373e7ecdfebe12e = L.map(
#                 &quot;map_d6d9b2c00742f1136373e7ecdfebe12e&quot;,
#                 {
#                     center: [22.0636, 113.2834],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1428285b1a9ccfab1fdef0b80df9d4f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1428285b1a9ccfab1fdef0b80df9d4f1.addTo(map_d6d9b2c00742f1136373e7ecdfebe12e);
#
#
#             var marker_bfe97a30642ca476de5caa86125dc2c7 = L.marker(
#                 [22.0064, 113.3763],
#                 {
# }
#             ).addTo(map_d6d9b2c00742f1136373e7ecdfebe12e);
#
#
#         var popup_9009a6611ba187fb3287d7963477d698 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3bdb85ccb6f4447cb72f2d221016ab5 = $(`&lt;div id=&quot;html_e3bdb85ccb6f4447cb72f2d221016ab5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_9009a6611ba187fb3287d7963477d698.setContent(html_e3bdb85ccb6f4447cb72f2d221016ab5);
#
#
#
#         marker_bfe97a30642ca476de5caa86125dc2c7.bindPopup(popup_9009a6611ba187fb3287d7963477d698)
#         ;
#
#
#
#
#             var marker_758be05f1cd746153ee50e4bc9305a30 = L.marker(
#                 [22.119, 113.3572],
#                 {
# }
#             ).addTo(map_d6d9b2c00742f1136373e7ecdfebe12e);
#
#
#         var popup_ed201bd82566e6c83248dc16fc1b0821 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5c900dcc0b1ab1c699f278dff561fdf = $(`&lt;div id=&quot;html_f5c900dcc0b1ab1c699f278dff561fdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_ed201bd82566e6c83248dc16fc1b0821.setContent(html_f5c900dcc0b1ab1c699f278dff561fdf);
#
#
#
#         marker_758be05f1cd746153ee50e4bc9305a30.bindPopup(popup_ed201bd82566e6c83248dc16fc1b0821)
#         ;
#
#
#
#
#             var marker_576ef0bc1918993d444e02e0d161b284 = L.marker(
#                 [22.0653, 113.1167],
#                 {
# }
#             ).addTo(map_d6d9b2c00742f1136373e7ecdfebe12e);
#
#
#         var popup_398e501557140ed1a4f78ad3579f4c91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_519d6c6e4ecc85f6d2d62fd07956d6a4 = $(`&lt;div id=&quot;html_519d6c6e4ecc85f6d2d62fd07956d6a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_398e501557140ed1a4f78ad3579f4c91.setContent(html_519d6c6e4ecc85f6d2d62fd07956d6a4);
#
#
#
#         marker_576ef0bc1918993d444e02e0d161b284.bindPopup(popup_398e501557140ed1a4f78ad3579f4c91)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#用户自定义点位
import folium
from folium import Map
from folium.plugins import Draw
from pydantic import BaseModel

class Point(BaseModel):
    latitude: float
    longitude: float

def get_folium_map(center_point: Point, zoom_level: int = 14) -> Map:
    folium_map = folium.Map(
        location=[center_point.latitude, center_point.longitude], zoom_start=zoom_level)
    
    # 添加 Draw 插件，支持用户点击添加标记点
    draw = Draw(
        position='topleft',  # 工具栏位置
        draw_options={
            'marker': {'shapeOptions': {'color': '#ff0000'}},  # 标记样式自定义
        },
        edit_options={
            'remove': True,  # 允许删除标记
        }
    ).add_to(folium_map)
    
    return folium_map

# 示例中心点（可以根据需要调整）
center_point = Point(latitude=22.0636, longitude=113.2834)

folium_map = get_folium_map(center_point)
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94ee33ee699359939bad8a8fed88f3c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94ee33ee699359939bad8a8fed88f3c8&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94ee33ee699359939bad8a8fed88f3c8 = L.map(
#                 &quot;map_94ee33ee699359939bad8a8fed88f3c8&quot;,
#                 {
#                     center: [22.0636, 113.2834],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_418aea1fdddd415673a2f24e076b9019 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_418aea1fdddd415673a2f24e076b9019.addTo(map_94ee33ee699359939bad8a8fed88f3c8);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {&quot;marker&quot;: {&quot;shapeOptions&quot;: {&quot;color&quot;: &quot;#ff0000&quot;}}},
#               edit: {&quot;remove&quot;: true},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_ac620003d23996fc0f77449e25e53e55 =
#                     new L.featureGroup().addTo(
#                         map_94ee33ee699359939bad8a8fed88f3c8
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_ac620003d23996fc0f77449e25e53e55;
#             var draw_control_ac620003d23996fc0f77449e25e53e55 = new L.Control.Draw(
#                 options
#             ).addTo( map_94ee33ee699359939bad8a8fed88f3c8 );
#             map_94ee33ee699359939bad8a8fed88f3c8.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_ac620003d23996fc0f77449e25e53e55.addLayer(layer);
#             });
#             map_94ee33ee699359939bad8a8fed88f3c8.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_ac620003d23996fc0f77449e25e53e55.addLayer(e.layer);
#             });
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## <a id='toc1_2_'></a>[Using the service](#toc0_)

# %% [markdown]
# ### <a id='toc1_2_1_'></a>[General options](#toc0_)

# %% [markdown]
# The general options are used in every OSRM service, read more about them [here](https://project-osrm.org/docs/v5.5.1/api/?language=cURL#general-options). Here is a table that summarizes the options with their description.
#
#
# | Parameter | Description |
# |-----------|-------------|
# | service | One of the following values: `route`, `nearest`, `table`, `match`, `trip`, `tile` |
# | version | Version of the protocol implemented by the service. `v1` for all OSRM 5.x installations |
# | profile | Mode of transportation, is determined statically by the Lua profile that is used to prepare the data using `osrm-extract`. Typically `car`, `bike` or `foot` if using one of the supplied profiles. |
# | coordinates | String of format `{longitude},{latitude};{longitude},{latitude};{longitude},{latitude} ...]` or `polyline({polyline})`. |
# | format | Only `json` is supported at the moment. This parameter is optional and defaults to `json`. |

# %% [markdown]
# ### <a id='toc1_2_2_'></a>[Making the request](#toc0_)

# %%
service = 'route'
version = 'v1'
# profile = 'driving'
profile = 'cycling'
# profile = 'walking'
host = 'http://localhost:5000'

# %% [markdown]
# The route endpoint follows this format: `/route/v1/{profile}/{coordinates}?alternatives={true|false}&steps={true|false}&geometries={polyline|polyline6|geojson}&overview={full|simplified|false}&annotations={true|false}`.
#
# To request the shortest path between three points, the order of the points is crucial. If you want the route from point 1 to point 2 to point 3, make sure to list them in that sequence.

# %%
import requests
#注意点的顺序
points = [ point_2, point_1,point_3]
coordinates = ';'.join(
    [f'{point.longitude},{point.latitude}' for point in points])

url = f"{host}/{service}/{version}/{profile}/{coordinates}?alternatives=true&overview=full&steps=true&geometries=geojson"

response = requests.get(url)
response.status_code
# Out:
# 200

# %% [markdown]
# The `200` status code signifies that the request was successful. Now, let's fetch the route and display it on the map.

# %%
data = response.json()
data.keys()
# Out:
# dict_keys(['code', 'routes', 'waypoints'])

# %%
routes = data['routes']
print(f"Found {len(routes)} route(s)")
# Out:
# Found 1 route(s)

# %% [markdown]
# Since we didn't include the `alternatives` option in the request, the response contains only one route. From this route, we can extract the `coordinates`, the `distance` in meters, and the `duration` in seconds.

# %%
#返回routes结果的坐标点、距离、时长
route = routes[0]
route_coordinates = route['geometry']["coordinates"]
route_distance = route["distance"]  # unit: meters
route_duration = route["duration"]  # unit: seconds

route_coordinates[:8]
# Out:
# [[113.357177, 22.119086],
#  [113.356749, 22.118987],
#  [113.356649, 22.118964],
#  [113.356045, 22.11883],
#  [113.355842, 22.118784],
#  [113.355754, 22.118765],
#  [113.355747, 22.118779],
#  [113.355737, 22.118792]]

# %% [markdown]
# ### <a id='toc1_2_3_'></a>[Plotting the path](#toc0_)

# %% [markdown]
# The route returned by `OSRM` is in the format `[[longitude, latitude], [longitude, latitude], ...]`. To plot the path on the Folium map, we need to swap the latitude and longitude for each point.

# %%
route_coordinates = [[point[1], point[0]] for point in route_coordinates]
route_coordinates[:5]
# Out:
# [[22.119086, 113.357177],
#  [22.118987, 113.356749],
#  [22.118964, 113.356649],
#  [22.11883, 113.356045],
#  [22.118784, 113.355842]]

# %%
folium_map = get_folium_map(center_point, [point_1, point_2, point_3])
popup_text = f"Distance: {route_distance} meters<br>Duration: {route_duration} seconds"
popup = folium.Popup(popup_text, max_width=300)

folium.PolyLine(
    locations=route_coordinates, color='blue', weight=5, popup=popup).add_to(folium_map)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a89a1cfdc522b0235bd127af6be8f2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a89a1cfdc522b0235bd127af6be8f2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a89a1cfdc522b0235bd127af6be8f2b = L.map(
#                 &quot;map_2a89a1cfdc522b0235bd127af6be8f2b&quot;,
#                 {
#                     center: [22.0636, 113.2834],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9e729f6454bd4f0407124a572a8c869 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a9e729f6454bd4f0407124a572a8c869.addTo(map_2a89a1cfdc522b0235bd127af6be8f2b);
#
#
#             var marker_25dbe871ea6ba9e9f5c5fadf8b65ef36 = L.marker(
#                 [22.0064, 113.3763],
#                 {
# }
#             ).addTo(map_2a89a1cfdc522b0235bd127af6be8f2b);
#
#
#         var popup_7a97b9a69e471bef56dd99bf4d69b0ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7299762e649da9ab4d30721a6e90599 = $(`&lt;div id=&quot;html_b7299762e649da9ab4d30721a6e90599&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_7a97b9a69e471bef56dd99bf4d69b0ea.setContent(html_b7299762e649da9ab4d30721a6e90599);
#
#
#
#         marker_25dbe871ea6ba9e9f5c5fadf8b65ef36.bindPopup(popup_7a97b9a69e471bef56dd99bf4d69b0ea)
#         ;
#
#
#
#
#             var marker_d53f25ee299b7555db72ab6b3f3888e6 = L.marker(
#                 [22.119, 113.3572],
#                 {
# }
#             ).addTo(map_2a89a1cfdc522b0235bd127af6be8f2b);
#
#
#         var popup_f032fb70751d2902abddb7821a682232 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb7f955ff1aee5d52006a5ce6483756c = $(`&lt;div id=&quot;html_cb7f955ff1aee5d52006a5ce6483756c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_f032fb70751d2902abddb7821a682232.setContent(html_cb7f955ff1aee5d52006a5ce6483756c);
#
#
#
#         marker_d53f25ee299b7555db72ab6b3f3888e6.bindPopup(popup_f032fb70751d2902abddb7821a682232)
#         ;
#
#
#
#
#             var marker_7c50a0a1da7f71a011437d34a165e4da = L.marker(
#                 [22.0653, 113.1167],
#                 {
# }
#             ).addTo(map_2a89a1cfdc522b0235bd127af6be8f2b);
#
#
#         var popup_b9072aa073920fa6a0fc5a8e07336423 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53d49c6c99dc8ceb763e94387ae9262c = $(`&lt;div id=&quot;html_53d49c6c99dc8ceb763e94387ae9262c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_b9072aa073920fa6a0fc5a8e07336423.setContent(html_53d49c6c99dc8ceb763e94387ae9262c);
#
#
#
#         marker_7c50a0a1da7f71a011437d34a165e4da.bindPopup(popup_b9072aa073920fa6a0fc5a8e07336423)
#         ;
#
#
#
#
#             var poly_line_e26ed7d66a54cd10c5d80666e7b2133c = L.polyline(
#                 [[22.119086, 113.357177], [22.118987, 113.356749], [22.118964, 113.356649], [22.11883, 113.356045], [22.118784, 113.355842], [22.118765, 113.355754], [22.118779, 113.355747], [22.118792, 113.355737], [22.1188, 113.355726], [22.118806, 113.355713], [22.11881, 113.355692], [22.118807, 113.35567], [22.118594, 113.354729], [22.118581, 113.354648], [22.118576, 113.354589], [22.118591, 113.354494], [22.118616, 113.354447], [22.118662, 113.354378], [22.118634, 113.354264], [22.11843, 113.354316], [22.118242, 113.354364], [22.117575, 113.354543], [22.117193, 113.354639], [22.116629, 113.354781], [22.116169, 113.354897], [22.115781, 113.355022], [22.115491, 113.355097], [22.115295, 113.355041], [22.115195, 113.354991], [22.115166, 113.355049], [22.115194, 113.355174], [22.115221, 113.355303], [22.115241, 113.355394], [22.115134, 113.355421], [22.114991, 113.355457], [22.114881, 113.355485], [22.114858, 113.355527], [22.115041, 113.355682], [22.115136, 113.356102], [22.115676, 113.358489], [22.115922, 113.359583], [22.115982, 113.359842], [22.11617, 113.360637], [22.1163, 113.361248], [22.11631, 113.361295], [22.116349, 113.361482], [22.116376, 113.361634], [22.116844, 113.363721], [22.117299, 113.365701], [22.117309, 113.365745], [22.11734, 113.365879], [22.117353, 113.365936], [22.117382, 113.366066], [22.117805, 113.367965], [22.118005, 113.368823], [22.118158, 113.369479], [22.118124, 113.369656], [22.118106, 113.3

# %% [markdown]
# ### <a id='toc1_2_4_'></a>[Exploring legs](#toc0_)

# %% [markdown]
# Each path is referred to as a `leg`. In our case, there are two legs: one that takes us from point 1 to point 2, and the other that connects point 2 to point 3. Each leg contains multiple steps, where each step provides details about how the route changes at a specific point, such as a turn, a continuation in a straight line, or the start/end of the route.
#
# leg包含steps

# %% [markdown]
# Let's draw the 2 legs.

# %%
folium_map = get_folium_map(center_point, [point_1, point_2, point_3])

colors = ['black', 'blue']
#循环 用颜色区分legs
legs = data["routes"][0]["legs"]
for i, leg in enumerate(legs):
    steps = leg["steps"]
    for step in steps:
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]
        popup_text = f"""
        Leg number {i + 1}<br>
        Leg distance: {leg['distance']} meters<br>
        Leg duration: {leg['duration']} seconds<br>
        """
        popup = folium.Popup(popup_text, max_width=300)
        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup)
        folium_map.add_child(polyline)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3005a24aa23ab291c73b1dd17c00593 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3005a24aa23ab291c73b1dd17c00593&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3005a24aa23ab291c73b1dd17c00593 = L.map(
#                 &quot;map_f3005a24aa23ab291c73b1dd17c00593&quot;,
#                 {
#                     center: [22.0636, 113.2834],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58e2f4083790c245436fdf12f6a928f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58e2f4083790c245436fdf12f6a928f9.addTo(map_f3005a24aa23ab291c73b1dd17c00593);
#
#
#             var marker_886e35adda8aacb315dc4956b1238ee3 = L.marker(
#                 [22.0064, 113.3763],
#                 {
# }
#             ).addTo(map_f3005a24aa23ab291c73b1dd17c00593);
#
#
#         var popup_06c53b9ffd73583c188f0cc384458d37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_648ac95b628a409cc8eac3b65eab3331 = $(`&lt;div id=&quot;html_648ac95b628a409cc8eac3b65eab3331&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_06c53b9ffd73583c188f0cc384458d37.setContent(html_648ac95b628a409cc8eac3b65eab3331);
#
#
#
#         marker_886e35adda8aacb315dc4956b1238ee3.bindPopup(popup_06c53b9ffd73583c188f0cc384458d37)
#         ;
#
#
#
#
#             var marker_4183a7a56859e4f80c89571119141d76 = L.marker(
#                 [22.119, 113.3572],
#                 {
# }
#             ).addTo(map_f3005a24aa23ab291c73b1dd17c00593);
#
#
#         var popup_ea49aad7ca0308d674ec61147cdfad4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07739c7747160549c436a7d37b36cb08 = $(`&lt;div id=&quot;html_07739c7747160549c436a7d37b36cb08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_ea49aad7ca0308d674ec61147cdfad4e.setContent(html_07739c7747160549c436a7d37b36cb08);
#
#
#
#         marker_4183a7a56859e4f80c89571119141d76.bindPopup(popup_ea49aad7ca0308d674ec61147cdfad4e)
#         ;
#
#
#
#
#             var marker_48efc5908dc3fc5df2df017028941aeb = L.marker(
#                 [22.0653, 113.1167],
#                 {
# }
#             ).addTo(map_f3005a24aa23ab291c73b1dd17c00593);
#
#
#         var popup_c3e30aad63628b7f1ab16d08a40ed98d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8713c9d7c656053b7a05597ac0c77108 = $(`&lt;div id=&quot;html_8713c9d7c656053b7a05597ac0c77108&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_c3e30aad63628b7f1ab16d08a40ed98d.setContent(html_8713c9d7c656053b7a05597ac0c77108);
#
#
#
#         marker_48efc5908dc3fc5df2df017028941aeb.bindPopup(popup_c3e30aad63628b7f1ab16d08a40ed98d)
#         ;
#
#
#
#
#             var poly_line_a4fcc2bcc852b80d87dfecc1c4e779fa = L.polyline(
#                 [[22.119086, 113.357177], [22.118987, 113.356749], [22.118964, 113.356649], [22.11883, 113.356045], [22.118784, 113.355842], [22.118765, 113.355754]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_f3005a24aa23ab291c73b1dd17c00593);
#
#
#         var popup_42cd4c4d3d8708d3f8826790e933f569 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_43a4b53ad041c094a329ba0703ea1304 = $(`&lt;div id=&quot;html_43a4b53ad041c094a329ba0703ea1304&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         Leg number 1&lt;br&gt;         Leg distance: 19176.1 meters&lt;br&gt;         Leg duration: 5002.5 seconds&lt;br&gt;         &lt;/div&gt;`)[0];
#                 popup_42cd4c4d3d8708d3f8826790e933f569.setContent(html_43a4b53ad041c094a329ba0703ea1304);
#
#
#
#         poly_line_a4fcc2bcc852b80d87dfecc1c4e779fa.bindPopup(popup_42cd4c4d3d8708d3f8826790e933f569)
#         ;

# %% [markdown]
# Let's focus on a single leg and break it down into its individual steps. Each step provides instructions on where to go, what action to take, and the distance to travel before transitioning to the next step.
#
# To illustrate, let's consider the first two segments of the leg.

# %%
folium_map = get_folium_map(
    point_1, [point_1, point_2, point_3], zoom_level=16)

colors = ['black', 'blue']
#legs里的每个steps中所含属性 duration, driving side(行驶侧), instruction（机动指令）,type of manuever(描述该核心动作) ，intersections（交通灯的数量）
legs = data["routes"][0]["legs"]
for leg in legs:
    steps = leg["steps"]
    for i, step in enumerate(steps[:3]):
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]
        popup_text = f"""
        Distance: {step['distance']} meters
        <br>Duration: {step['duration']} seconds
        <br>Name: {step['name']}
        <br>Driving side: {step['driving_side']}
        <br>Instruction: {step['maneuver']['modifier']}
        <br>Type of maneuver: {step['maneuver']['type']}
        <br>Intersections: {len(step['intersections'])}
        """
        popup = folium.Popup(popup_text, max_width=300)
        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup)
        folium_map.add_child(polyline)
    break

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98860de31ae223e74c607edc77843d8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98860de31ae223e74c607edc77843d8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98860de31ae223e74c607edc77843d8f = L.map(
#                 &quot;map_98860de31ae223e74c607edc77843d8f&quot;,
#                 {
#                     center: [22.0064, 113.3763],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d15430af2901f85309b946c762fb53f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d15430af2901f85309b946c762fb53f.addTo(map_98860de31ae223e74c607edc77843d8f);
#
#
#             var marker_457b7b05feb4b13fa3b1f2e83bb90423 = L.marker(
#                 [22.0064, 113.3763],
#                 {
# }
#             ).addTo(map_98860de31ae223e74c607edc77843d8f);
#
#
#         var popup_f48242027fa360fde91bb11b703c0491 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f1e2bc99b199d265692940454cb5c76 = $(`&lt;div id=&quot;html_8f1e2bc99b199d265692940454cb5c76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_f48242027fa360fde91bb11b703c0491.setContent(html_8f1e2bc99b199d265692940454cb5c76);
#
#
#
#         marker_457b7b05feb4b13fa3b1f2e83bb90423.bindPopup(popup_f48242027fa360fde91bb11b703c0491)
#         ;
#
#
#
#
#             var marker_94b0cf9fb5ad15716c6bd3b3693003bf = L.marker(
#                 [22.119, 113.3572],
#                 {
# }
#             ).addTo(map_98860de31ae223e74c607edc77843d8f);
#
#
#         var popup_91a1e7e425555a1804f41d23eb6e7349 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47226f39642e3ec9fab4ec2234e5e0ad = $(`&lt;div id=&quot;html_47226f39642e3ec9fab4ec2234e5e0ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_91a1e7e425555a1804f41d23eb6e7349.setContent(html_47226f39642e3ec9fab4ec2234e5e0ad);
#
#
#
#         marker_94b0cf9fb5ad15716c6bd3b3693003bf.bindPopup(popup_91a1e7e425555a1804f41d23eb6e7349)
#         ;
#
#
#
#
#             var marker_5ddcf1d7e699ccb86e5e4b5d3e572f2f = L.marker(
#                 [22.0653, 113.1167],
#                 {
# }
#             ).addTo(map_98860de31ae223e74c607edc77843d8f);
#
#
#         var popup_f9dde6a2cd770d7b1dba5ce6246886e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25af1901536b765901d405fd451b4c0e = $(`&lt;div id=&quot;html_25af1901536b765901d405fd451b4c0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_f9dde6a2cd770d7b1dba5ce6246886e5.setContent(html_25af1901536b765901d405fd451b4c0e);
#
#
#
#         marker_5ddcf1d7e699ccb86e5e4b5d3e572f2f.bindPopup(popup_f9dde6a2cd770d7b1dba5ce6246886e5)
#         ;
#
#
#
#
#             var poly_line_d26b82a34496cd5a83a3e47a20616dd1 = L.polyline(
#                 [[22.119086, 113.357177], [22.118987, 113.356749], [22.118964, 113.356649], [22.11883, 113.356045], [22.118784, 113.355842], [22.118765, 113.355754]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_98860de31ae223e74c607edc77843d8f);
#
#
#         var popup_59957788b56061e2e7979f3a1b612d80 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_bcf6bdb1029ee5884b61177cd235abc8 = $(`&lt;div id=&quot;html_bcf6bdb1029ee5884b61177cd235abc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         Distance: 151.1 meters         &lt;br&gt;Duration: 137 seconds         &lt;br&gt;Name:          &lt;br&gt;Driving side: right         &lt;br&gt;Instruction: left         &lt;br&gt;Type of maneuver: depart         &lt;br&gt;Intersections: 2         &lt;/div&gt;`)[0];
#                 popup_59957788b56061e2e7979f3a1b612d80.setContent(html_bcf6bdb1029ee5884b61177cd235abc8);

# %% [markdown]
# Each segment contains details such as the `distance`, `duration`, `name` of the road, and other relevant information. This helps to describe the specifics of the route for each step, guiding us on the actions to take and the duration and distance of each segment.

# %%
from pprint import pprint

leg = data["routes"][0]["legs"][0]
step = leg["steps"][0]
pprint(step)
#- location: [经度, 纬度]，交差点位置。
#- bearings: 数组，路口可达方向的轴承（度数，0°=北，顺时针）。第一个交差点只有 256°（西南方向）。第二个有多个（45° 到 345°，几乎全方向）。
#- entry: 布尔数组，表示从哪些轴承可进入（True=可进入）。第二个交差点有 5 个入口可用。
#- in / out: 进入/离开的轴承索引。这里第一个交差点是起点（out=0），第二个是终点（in=1, out=4，表示从轴承1进入，从轴承4离开）。总共 2 个交差点，表明路段简单
# Out:
# {'distance': 151.1,
#  'driving_side': 'right',
#  'duration': 137,
#  'geometry': {'coordinates': [[113.357177, 22.119086],
#                               [113.356749, 22.118987],
#                               [113.356649, 22.118964],
#                               [113.356045, 22.11883],
#                               [113.355842, 22.118784],
#                               [113.355754, 22.118765]],
#               'type': 'LineString'},
#  'intersections': [{'bearings': [256],
#                     'entry': [True],
#                     'location': [113.357177, 22.119086],
#                     'out': 0},
#                    {'bearings': [45, 75, 105, 165, 255, 345],
#                     'entry': [True, False, True, True, True, True],
#                     'in': 1,
#                     'location': [113.355842, 22.118784],
#                     'out': 4}],
#  'maneuver': {'bearing_after': 256,
#               'bearing_before': 0,
#               'location': [113.357177, 22.119086],
#               'modifier': 'left',
#               'type': 'depart'},
#  'mode': 'pushing bike',
#  'name': '',
#  'weight': 137}

# %% [markdown]
# Let's visualize one step of the route by drawing it on the map. We will display the relevant information as a popup, which can include details such as the distance, duration, road name, etc. Additionally, for the `bearing` angle, we will draw a line in the direction of movement to represent the heading at that point.

# %%
import math


def add_compass(folium_map: Map, location: tuple, bearing: int, size: int = 50):

    lat, lon = location
    end_lat = lat + (math.cos(math.radians(bearing)) * size * 1e-5)
    end_lon = lon + (math.sin(math.radians(bearing)) * size * 1e-5)

    folium.Marker(
        location=location,
        icon=folium.DivIcon(
            html="""<div style="font-size: 12px; color: red;">📍</div>"""),
        tooltip=f"Bearing: {bearing}°",
    ).add_to(folium_map)

    folium.PolyLine(
        locations=[location, (end_lat, end_lon)],
        color="red",
        weight=2,
    ).add_to(folium_map)


folium_map = get_folium_map(
    point_1, [point_1, point_2, point_3], zoom_level=16)

colors = ['black', 'blue']
legs = data["routes"][0]["legs"]
for leg in legs[:1]:
    steps = leg["steps"]
    for i, step in enumerate(steps[:1]):
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]

        popup_text = f"""
        Distance: {step['distance']} meters
        <br>Duration: {step['duration']} seconds
        <br>Name: {step['name']}
        <br>Driving side: {step['driving_side']}
        <br>Instruction: {step['maneuver']['modifier']}
        <br>Type of maneuver: {step['maneuver']['type']}
        <br>Intersections: {len(step['intersections'])}
        """
        popup = folium.Popup(popup_text, max_width=300)

        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup
        )
        folium_map.add_child(polyline)

        maneuver_location = step["maneuver"]["location"]
        bearing = step["maneuver"].get("bearing_after", 0)
        add_compass(
            folium_map=folium_map,
            location=(maneuver_location[1], maneuver_location[0]),
            bearing=bearing
        )

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4c604bda90794d6d3750f7e67e2dd4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4c604bda90794d6d3750f7e67e2dd4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4c604bda90794d6d3750f7e67e2dd4a = L.map(
#                 &quot;map_c4c604bda90794d6d3750f7e67e2dd4a&quot;,
#                 {
#                     center: [22.0064, 113.3763],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_943234f5c0efa35c367ec15facd39696 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_943234f5c0efa35c367ec15facd39696.addTo(map_c4c604bda90794d6d3750f7e67e2dd4a);
#
#
#             var marker_16d01c2bb1b9a66c7bd8bde4289c73da = L.marker(
#                 [22.0064, 113.3763],
#                 {
# }
#             ).addTo(map_c4c604bda90794d6d3750f7e67e2dd4a);
#
#
#         var popup_08b1854d4d588d4cb7a5f6cfcefac21b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fd3f0156ca94db09c2fbdc83269620e = $(`&lt;div id=&quot;html_4fd3f0156ca94db09c2fbdc83269620e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_08b1854d4d588d4cb7a5f6cfcefac21b.setContent(html_4fd3f0156ca94db09c2fbdc83269620e);
#
#
#
#         marker_16d01c2bb1b9a66c7bd8bde4289c73da.bindPopup(popup_08b1854d4d588d4cb7a5f6cfcefac21b)
#         ;
#
#
#
#
#             var marker_1aff919b51c6fb1947ebb05092d31774 = L.marker(
#                 [22.119, 113.3572],
#                 {
# }
#             ).addTo(map_c4c604bda90794d6d3750f7e67e2dd4a);
#
#
#         var popup_942fa5d61bb92dbf6fff50ab955424f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c8bb030b512a87fb77a51745be47958 = $(`&lt;div id=&quot;html_0c8bb030b512a87fb77a51745be47958&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_942fa5d61bb92dbf6fff50ab955424f7.setContent(html_0c8bb030b512a87fb77a51745be47958);
#
#
#
#         marker_1aff919b51c6fb1947ebb05092d31774.bindPopup(popup_942fa5d61bb92dbf6fff50ab955424f7)
#         ;
#
#
#
#
#             var marker_ffc474c519c63169c518509a2aca2ad4 = L.marker(
#                 [22.0653, 113.1167],
#                 {
# }
#             ).addTo(map_c4c604bda90794d6d3750f7e67e2dd4a);
#
#
#         var popup_6479fec9f49f687898e72ccaf6751ac8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb375efc2d7180693965b5cc3a639e77 = $(`&lt;div id=&quot;html_eb375efc2d7180693965b5cc3a639e77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_6479fec9f49f687898e72ccaf6751ac8.setContent(html_eb375efc2d7180693965b5cc3a639e77);
#
#
#
#         marker_ffc474c519c63169c518509a2aca2ad4.bindPopup(popup_6479fec9f49f687898e72ccaf6751ac8)
#         ;
#
#
#
#
#             var poly_line_5c4c057484ad58eaca7d92a9f0d1681f = L.polyline(
#                 [[22.119086, 113.357177], [22.118987, 113.356749], [22.118964, 113.356649], [22.11883, 113.356045], [22.118784, 113.355842], [22.118765, 113.355754]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_c4c604bda90794d6d3750f7e67e2dd4a);
#
#
#         var popup_5f8ef8a464fbf408629697887fd851e7 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_38fc211bd036568562cff316e29d4e8d = $(`&lt;div id=&quot;html_38fc211bd036568562cff316e29d4e8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         Distance: 151.1 meters         &lt;br&gt;Duration: 137 seconds         &lt;br&gt;Name:          &lt;br&gt;Driving side: right         &lt;br&gt;Instruction: left         &lt;br&gt;Type of maneuver: depart         &lt;br&gt;Intersections: 2         &lt;/div&gt;`)[0];
#                 popup_5f8ef8a464fbf408629697887fd851e7.setContent(html_38fc211bd036568562cff316e29d4e8d);

# %% [markdown]
# ### <a id='toc1_2_5_'></a>[Exploring the intersections](#toc0_)

# %% [markdown]
# Let’s explain what the values for `intersection` represent. Starting with the first step in the first leg, we encounter 2 objects, each providing detailed information about the road layout at the intersection.
#
# - `out`: This indicates the index of the outgoing bearing from the intersection. In the first object, `out` is 0 because there is only one available bearing angle. In the second object, `out` is 2, as there are three possible options to choose from.
# - `in`: The index of the incoming bearing, representing the road you arrived on.
# - `entry`: A list of booleans, where each value corresponds to a `bearing` in the bearings array. A `True` value means the road is accessible, while a `False` value means it is not.
# - `bearings`: An array of compass bearings (in degrees) that represent all the possible directions (roads) at this intersection. Each bearing corresponds to a road radiating out from the intersection.
# - `location`: The precise [longitude, latitude] coordinates of the intersection.

# %%
from pprint import pprint

leg = data["routes"][0]["legs"][0]
step = leg["steps"][0]
intersections = step["intersections"]
pprint(intersections)
# Out:
# [{'bearings': [256],
#   'entry': [True],
#   'location': [113.357177, 22.119086],
#   'out': 0},
#  {'bearings': [45, 75, 105, 165, 255, 345],
#   'entry': [True, False, True, True, True, True],
#   'in': 1,
#   'location': [113.355842, 22.118784],
#   'out': 4}]

# %% [markdown]
# Let's plot the `bearing` directions on the map to visualize what these values represent. The first intersection object contains only one bearing value, indicating that there is only one option to choose from.

# %%
import math


def add_compass(
    folium_map: Map,
    location: tuple,
    bearing: int,
    size: int = 50,
    color: str = "red",
    weight: int = 2
):
    lat, lon = location
    end_lat = lat + (math.cos(math.radians(bearing)) * size * 1e-5)
    end_lon = lon + (math.sin(math.radians(bearing)) * size * 1e-5)

    folium.Marker(
        location=location,
        icon=folium.DivIcon(
            html="""<div style="font-size: 12px; color: red;">📍</div>"""),
    ).add_to(folium_map)

    folium.PolyLine(
        locations=[location, (end_lat, end_lon)],
        color=color,
        weight=weight,
        tooltip=f"Bearing: {bearing}°",
    ).add_to(folium_map)


folium_map = get_folium_map(
    point_1, [point_1, point_2, point_3], zoom_level=18)

colors = ['black', 'blue']
legs = data["routes"][0]["legs"]
for leg in legs[:1]:
    steps = leg["steps"]
    for i, step in enumerate(steps[:1]):
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]

        popup_text = f"""
        Distance: {step['distance']} meters
        <br>Duration: {step['duration']} seconds
        <br>Name: {step['name']}
        <br>Driving side: {step['driving_side']}
        <br>Instruction: {step['maneuver']['modifier']}
        <br>Type of maneuver: {step['maneuver']['type']}
        <br>Intersections: {len(step['intersections'])}
        """
        popup = folium.Popup(popup_text, max_width=300)

        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup
        )
        folium_map.add_child(polyline)

        intersections = step["intersections"]
        for intersection in intersections[:1]:
            location = intersection["location"]
            bearings = intersection["bearings"]
            for j, bearing in enumerate(bearings):
                allowed_for_traversal = intersection["entry"][j]
                add_compass(
                    folium_map=folium_map,
                    location=(location[1], location[0]),
                    bearing=bearing,
                    color="green" if allowed_for_traversal else "red",
                    weight=5
                )

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c9f4e88bce81f99f803db848b5cd349 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c9f4e88bce81f99f803db848b5cd349&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c9f4e88bce81f99f803db848b5cd349 = L.map(
#                 &quot;map_0c9f4e88bce81f99f803db848b5cd349&quot;,
#                 {
#                     center: [22.0064, 113.3763],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 18,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49ed828c7617f35bc57da5bc64bf4e92 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49ed828c7617f35bc57da5bc64bf4e92.addTo(map_0c9f4e88bce81f99f803db848b5cd349);
#
#
#             var marker_954ba6c82a8a829267767d4d5865603f = L.marker(
#                 [22.0064, 113.3763],
#                 {
# }
#             ).addTo(map_0c9f4e88bce81f99f803db848b5cd349);
#
#
#         var popup_9a1579236e822882b1ad5cc6ea3cee70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_772b0f4492a77af4e5f67a060d715a24 = $(`&lt;div id=&quot;html_772b0f4492a77af4e5f67a060d715a24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_9a1579236e822882b1ad5cc6ea3cee70.setContent(html_772b0f4492a77af4e5f67a060d715a24);
#
#
#
#         marker_954ba6c82a8a829267767d4d5865603f.bindPopup(popup_9a1579236e822882b1ad5cc6ea3cee70)
#         ;
#
#
#
#
#             var marker_4c249b1e4a5e48d865c22738cd536645 = L.marker(
#                 [22.119, 113.3572],
#                 {
# }
#             ).addTo(map_0c9f4e88bce81f99f803db848b5cd349);
#
#
#         var popup_9590fc25521ca1d77f4e198768f40dcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6019d8eefc529c76ca154a7d638475b3 = $(`&lt;div id=&quot;html_6019d8eefc529c76ca154a7d638475b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_9590fc25521ca1d77f4e198768f40dcb.setContent(html_6019d8eefc529c76ca154a7d638475b3);
#
#
#
#         marker_4c249b1e4a5e48d865c22738cd536645.bindPopup(popup_9590fc25521ca1d77f4e198768f40dcb)
#         ;
#
#
#
#
#             var marker_511a1a2bf8b15419de55b5fda731d90f = L.marker(
#                 [22.0653, 113.1167],
#                 {
# }
#             ).addTo(map_0c9f4e88bce81f99f803db848b5cd349);
#
#
#         var popup_268eddc8c4fd54e851714fb6c4a231d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_810e860b3d28302f9ec0933c51f624c5 = $(`&lt;div id=&quot;html_810e860b3d28302f9ec0933c51f624c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_268eddc8c4fd54e851714fb6c4a231d6.setContent(html_810e860b3d28302f9ec0933c51f624c5);
#
#
#
#         marker_511a1a2bf8b15419de55b5fda731d90f.bindPopup(popup_268eddc8c4fd54e851714fb6c4a231d6)
#         ;
#
#
#
#
#             var poly_line_4be224be09937d793666c210a56e0640 = L.polyline(
#                 [[22.119086, 113.357177], [22.118987, 113.356749], [22.118964, 113.356649], [22.11883, 113.356045], [22.118784, 113.355842], [22.118765, 113.355754]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_0c9f4e88bce81f99f803db848b5cd349);
#
#
#         var popup_6f10e93ecae4a5a86516e39aee479e94 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_93bec92837a992836a68bd6c4492c785 = $(`&lt;div id=&quot;html_93bec92837a992836a68bd6c4492c785&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         Distance: 151.1 meters         &lt;br&gt;Duration: 137 seconds         &lt;br&gt;Name:          &lt;br&gt;Driving side: right         &lt;br&gt;Instruction: left         &lt;br&gt;Type of maneuver: depart         &lt;br&gt;Intersections: 2         &lt;/div&gt;`)[0];
#                 popup_6f10e93ecae4a5a86516e39aee479e94.setContent(html_93bec92837a992836a68bd6c4492c785);

# %% [markdown]
# After a few steps, we encounter an intersection with three bearing values. These correspond to going straight, turning back, or turning left. The `entry` value for the first bearing, which corresponds to going back, is set to `False`, meaning we cannot reverse our direction. The other two routes, however, can be taken because their `entry` values are set to `True`.

# %%
import math


def add_compass(
    folium_map: Map,
    location: tuple,
    bearing: int,
    size: int = 50,
    color: str = "red",
    weight: int = 2
):
    lat, lon = location
    end_lat = lat + (math.cos(math.radians(bearing)) * size * 1e-5)
    end_lon = lon + (math.sin(math.radians(bearing)) * size * 1e-5)

    folium.Marker(
        location=location,
        icon=folium.DivIcon(
            html="""<div style="font-size: 12px; color: black;">📍</div>"""),
    ).add_to(folium_map)

    folium.PolyLine(
        locations=[location, (end_lat, end_lon)],
        color=color,
        weight=weight,
        tooltip=f"Bearing: {bearing}°"
    ).add_to(folium_map)


folium_map = get_folium_map(
    point_1, [point_1, point_2, point_3], zoom_level=20)

colors = ['black', 'blue']
legs = data["routes"][0]["legs"]
for leg in legs[:1]:
    steps = leg["steps"]
    for i, step in enumerate(steps[:1]):
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]

        popup_text = f"""
        Distance: {step['distance']} meters
        <br>Duration: {step['duration']} seconds
        <br>Name: {step['name']}
        <br>Driving side: {step['driving_side']}
        <br>Instruction: {step['maneuver']['modifier']}
        <br>Type of maneuver: {step['maneuver']['type']}
        <br>Intersections: {len(step['intersections'])}
        """
        popup = folium.Popup(popup_text, max_width=300)

        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup
        )
        folium_map.add_child(polyline)

        intersections = step["intersections"]
        for intersection in intersections[1:]:
            location = intersection["location"]
            bearings = intersection["bearings"]
            for j, bearing in enumerate(bearings):
                allowed_for_traversal = intersection["entry"][j]
                add_compass(
                    folium_map=folium_map,
                    location=(location[1], location[0]),
                    bearing=bearing,
                    color="green" if allowed_for_traversal else "red",
                    weight=5
                )

folium_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 import math
#       4 def add_compass(
# ----> 5     folium_map: Map,
#       6     location: tuple,
#       7     bearing: int,
#       8     size: int = 50,
#       9     color: str = "red",
#      10     weight: int = 2
#      11 ):
#      12     lat, lon = location
#      13     end_lat = lat + (math.cos(math.radians(bearing)) * size * 1e-5)
#
# NameError: name 'Map' is not defined

# %% [markdown]
# ### <a id='toc1_2_6_'></a>[Exploring the cost of the route](#toc0_)

# %% [markdown]
# Now, let's discuss `weights`. The `weight` value represents the cost of the route based on the profile's weighting algorithm. In this case, the weight is 499.8. With the default profile, the weight corresponds to the route's duration, but this can be modified in the `car` profile, which you can find [here](https://github.com/Project-OSRM/osrm-backend/blob/master/profiles/car.lua#L23).
#
# If you're using a different profile, such as the [bike](https://github.com/Project-OSRM/osrm-backend/blob/master/profiles/bicycle.lua#L22) or [foot](https://github.com/Project-OSRM/osrm-backend/blob/master/profiles/foot.lua#L14) profiles, make sure to adjust the respective files.

# %%
weight = route["weight"]
weight_name = route["weight_name"]
duration = route["duration"]
distance = route["distance"]

print(f"Weight: {weight} - {weight_name}")
print(f"Duration: {duration} seconds")
print(f"Distance: {distance} meters")
# Out:
# Weight: 499.8 - routability
# Duration: 499.8 seconds
# Distance: 6042.4 meters

# %% [markdown]
# ### <a id='toc1_2_7_'></a>[Alternative routes](#toc0_)

# %% [markdown]
# By default, OSRM provides a single route corresponding to the shortest path. To view alternative routes, you need to enable the `alternatives` option and specify the number of alternatives you'd like to receive.
#
# Note: Although you can request alternative routes, there is no guarantee that they will be available.

# %%
import requests

points = [point_1, point_2, point_3]
coordinates = ';'.join(
    [f'{point.longitude},{point.latitude}' for point in points])

url = f"{host}/{service}/{version}/{profile}/{
    coordinates}?alternatives=3&overview=full&steps=true&geometries=geojson"

response = requests.get(url)
data = response.json()
routes = data['routes']
print(f"Found {len(routes)} route(s)")
# Out:
#   Cell In[24], line 7
#     url = f"{host}/{service}/{version}/{profile}/{
#                                                   ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# The note confirms that even with `alternatives` set to 3, only one route was returned. However, if you're interested, you can modify certain values in the source code to force OSRM to return an alternative route. For more details, check this [thread](https://github.com/Project-OSRM/osrm-backend/issues/5663).
